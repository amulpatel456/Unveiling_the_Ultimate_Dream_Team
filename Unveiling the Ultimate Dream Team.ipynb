# %% [markdown]
# # Unveiling the Ultimate Dream Team

# %% [markdown]
# ##  The All-Time Best Playing 11 in the Indian Premier League (IPL)

# %% [markdown]
# ![268be02061a78cdf9ae1b83fdeb0ae44.jpg](data:image/jpeg;base64,...)
#
#
# **Cricket** is a bat-and-ball game played between two teams of eleven players. Refer https://en.wikipedia.org/wiki/Cricket for details.
#
# **T20 Cricket** game is the shortest version of the game. It gets completed in 3-4 hours. There are two innings (one for each team). Each innings consists of 20 overs (6 legal balls to bowl) in an over. So each team gets to bat 20 overs (20 * 6 balls = 120 legal deliveries max) or until they loose 10 wickets (batsman getting out). T20 version has gained popularity in the last 15 years (thanks to India's inaugural T20 world cup win in 2007 and followed by the formation of IPL)
#
# **Indian Premier League(IPL)** is a professional Twenty20 cricket league in India contested during March or April and May of every year by different teams representing different cities in India. The league was founded by the Board of Control for Cricket in India(BCCI) in 2008.

# %% [markdown]
# ## Project Description

# %% [markdown]
# The goal of this project is to identify the all-time best playing 11 for an IPL team based on players' performance in the Indian Premier League (IPL). The team composition will be determined by considering the ratio of players in successful teams from recent events, such as the T20 Cricket World Cup and the previous year's IPL-winning team.
#
# The playing 11 will consist of the following ratio of players:
#
# *  4 Batters
# *  3 All-Rounders
# *  1 keeper
# *  3 Bowlers
#
# The project will involve analyzing extensive data from past IPL seasons, considering various parameters such as batting averages, strike rates, bowling averages, economy rates, wicketkeeping performances, and all-round contributions. These data-driven insights will be utilized to identify the best players for each category and determine their positions in the all-time best playing 11.
#
# By creating visualizations and presenting the findings in a concise and understandable manner, this project aims to facilitate decision-making for stakeholders, even those without a technical background. The resulting all-time best playing 11 will serve as a valuable resource for fans, team management, and cricket enthusiasts, providing insights into the most successful and impactful players in the history of the IPL.
#
# #### DataSet
#
# This dataset focuses on the IPL player records up until the beginning of the most recent season. It specifically includes data for active players who participated in the previous season, while excluding past players who did not participate in that season. The dataset consists of the following variables: Player Name, Team, Nationality, Player Type, Capped (whether the player has been capped by their national team), Matches Played, Runs, Average (batting average), Strike Rate, Wickets, Bowling Average, Economy, Bowling Strike Rate, Catches, Run Outs, and Stumps.
#
#
# #### Data Dictionary
#
# Matches Played: This parameter indicates the number of matches a player has participated in.
#
# Runs: The higher the runs scored by a player, the better their performance with the bat.
#
# Batting Average: A higher batting average indicates a player's consistency and ability to score runs consistently. Therefore, a higher average is considered better.
#
# Strike Rate: The strike rate measures how quickly a batsman scores runs. A higher strike rate suggests that a player is scoring runs at a faster pace.
#
# Wickets: This parameter represents the number of wickets taken by a bowler.
#
# Bowling Average: A lower bowling average is considered better as it indicates that the bowler concedes fewer runs per wicket taken. A lower average suggests the bowler's effectiveness in bowling.
#
# Economy: Economy rate indicates how many runs a bowler concedes per over. A lower economy rate is preferable as it shows that the bowler is restricting the flow of runs effectively.
#
# Bowling Strike Rate: The bowling strike rate measures the average number of balls bowled by a bowler to take a wicket. A lower strike rate suggests that the bowler is taking wickets more frequently.
#
# Catches: The number of catches taken by a player reflects their fielding ability.
#
# Run Outs: This parameter represents the number of run-outs executed by a player, indicating their effectiveness in fielding and throwing accurately.
#
# Stumps: The number of stumpings made by a wicket-keeper indicates their skill in dismissing batsmen.

# %% [markdown]
# ## Data Analysis Using Python

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("IPLData.csv")

# %%
data
# Out:
#          Player Name       Team Nationality Player_Type  Capped  \
# 0     Shikhar Dhawan     Punjab      Indian      Batter       1
# 1      Shreyas Iyer     Kolkata      Indian      Batter       1
# 2     Faf Du Plessis  Bangalore    Overseas      Batter       1
# 3     Manish Pandey     Lucknow      Indian      Batter       1
# 4    Shimron Hetmyer  Rajasthan    Overseas      Batter       1
# ..               ...        ...         ...         ...     ...
# 230     Ravi Bishnoi    Lucknow      Indian     Bowler        1
# 231  Ruturaj Gaikwad    Chennai      Indian      Batter       1
# 232    Sunil Narine     Kolkata    Overseas  Allrounder       1
# 233  Kieron Pollard      Mumbai    Overseas  Allrounder       1
# 234    Anrich Nortje      Delhi    Overseas     Bowler        1
#
#      Matches_Played    Runs  Average  Strike_Rate  Wickets  Bowling_average  \
# 0             192.0  5783.0    34.63       126.60      4.0            16.50
# ...

# %%
data.describe()
# Out:
#            Capped  Matches_Played         Runs     Average  Strike_Rate  \
# count  235.000000      215.000000   165.000000  161.000000   163.000000
# mean     0.838298       43.897674   840.575758   21.792391   121.009939
# std      0.561802       48.695302  1270.341831   11.664156    30.739189
# min      0.000000        1.000000     0.000000    0.000000     0.000000
# 25%      0.500000       11.500000    67.000000   13.800000   112.635000
# 50%      1.000000       25.000000   289.000000   22.410000   128.630000
# 75%      1.000000       56.000000   954.000000   29.300000   137.550000
# max      2.000000      220.000000  6283.000000   58.500000   190.240000
#
#           Wickets  Bowling_average     Economy  Bowling_Strike_Rate  \
# count  140.000000       135.000000  143.000000           119.000000
# mean    31.485714        32.907185    8.223182            24.686134
# std     36.872420        18.191441    1.223541            12.982049
# ...

# %%
data.isna().sum()
# Out:
# Player Name              0
# Team                     0
# Nationality              0
# Player_Type              0
# Capped                   0
# Matches_Played          20
# Runs                    70
# Average                 74
# Strike_Rate             72
# Wickets                 95
# Bowling_average        100
# Economy                 92
# Bowling_Strike_Rate    116
# Catches                208
# Run_outs               208
# Stumps                 208
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player Name          235 non-null    object
#  1   Team                 235 non-null    object
#  2   Nationality          235 non-null    object
#  3   Player_Type          235 non-null    object
#  4   Capped               235 non-null    int64
#  5   Matches_Played       215 non-null    float64
#  6   Runs                 165 non-null    float64
#  7   Average              161 non-null    float64
#  8   Strike_Rate          163 non-null    float64
#  9   Wickets              140 non-null    float64
#  10  Bowling_average      135 non-null    float64
#  11  Economy              143 non-null    float64
#  12  Bowling_Strike_Rate  119 non-null    float64
#  13  Catches              27 non-null     float64
#  14  Run_outs             27 non-null     float64
# ...

# %% [markdown]
# ## Cleaning The Data

# %% [markdown]
# In the above data, the players can be initially segragated based on following parameters
#
# 1. Capped - Batters, Bowlers, Allrounders, Wicket Keeper
# 2. Uncapped - Batters, Bowlers, Allrounders, Wicket Keeper
#
# The uncapped players are playing the IPL for the first time, or relevent data is not available therefore we have used their demostic T20 performances, and T20 International Performances.

# %%
#segregating data - capped batters

batters = data.loc[(data["Player_Type"] == "Batter")]

batters_new = batters.loc[(batters["Capped"] == 1)]

Capped_Batters = batters_new[['Player Name',	'Team',	'Nationality', 'Matches_Played',	'Runs',	'Average',	'Strike_Rate']]

# %%
Capped_Batters.head()
# Out:
#        Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 0   Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 1    Shreyas Iyer     Kolkata      Indian            87.0  2375.0    31.67
# 2   Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 3   Manish Pandey     Lucknow      Indian           154.0  3560.0    30.69
# 4  Shimron Hetmyer  Rajasthan    Overseas            31.0   517.0    25.85
#
#    Strike_Rate
# 0       126.60
# 1       123.96
# 2       131.09
# 3       121.83
# 4       151.17

# %%
#segregating data - capped bowlers

bowlers = data.loc[(data["Player_Type"] == "Bowler ")]

bowlers_new =  bowlers.loc[(bowlers["Capped"] == 1)]

Capped_Bowlers = bowlers_new[['Player Name','Team','Nationality', 'Matches_Played',	'Wickets','Bowling_average','Economy','Bowling_Strike_Rate']]

# %%
Capped_Bowlers.head()
# Out:
#         Player Name       Team Nationality  Matches_Played  Wickets  \
# 36   Kagiso Rabada      Punjab    Overseas            50.0     76.0
# 37     Trent Boult   Rajasthan    Overseas            62.0     76.0
# 38  Mohammad Shami     Gujarat      Indian            77.0     79.0
# 39      T Natarajan  Hyderabad      Indian            24.0     20.0
# 40   Deepak Chahar     Chennai      Indian            63.0     59.0
#
#     Bowling_average  Economy  Bowling_Strike_Rate
# 36            20.53     8.21                15.00
# 37            26.09     8.40                18.64
# 38            30.41     8.63                21.14
# 39            34.40     8.24                25.05
# 40            29.19     7.80                22.44

# %%
#segregating data - capped keepers

keepers = data.loc[(data["Player_Type"] == "Keeper")]

keepers_new =  keepers.loc[( keepers["Capped"] == 1)] 

Capped_keepers = keepers_new[['Player Name','Team','Nationality', 'Matches_Played',	'Runs','Average','Strike_Rate', 'Catches','Run_outs','Stumps']]

# %%
Capped_keepers.head()
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0     31.3
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0     29.4
# 107     Ishan Kishan     Mumbai      Indian            61.0  1452.0     28.5
# 108   Jonny Bairstow     Punjab    Overseas            28.0  1038.0     41.5
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0     25.8
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 105        130.9     53.0       0.0    14.0
# 106        127.5     58.0      12.0     2.0
# 107        136.3     19.0       1.0     2.0
# 108        142.2     18.0       1.0     4.0
# 109        129.7    123.0      14.0    32.0

# %%
#segregating data - capped Allrounders

Allrounders = data.loc[(data["Player_Type"] == "Allrounder")]

Allrounders_new =  Allrounders.loc[( Allrounders["Capped"] == 1) ]

Capped_Allrounders = Allrounders_new[['Player Name','Team','Nationality', 'Matches_Played','Runs','Average','Strike_Rate', 'Wickets','Bowling_average',	'Economy','Bowling_Strike_Rate']]

# %%
Capped_Allrounders.head()
# Out:
#               Player Name       Team Nationality  Matches_Played    Runs  \
# 127  Ravichandran Ashwin   Rajasthan      Indian           167.0   456.0
# 128          Pat Cummins     Kolkata    Overseas            37.0   316.0
# 129         Dwayne Bravo     Chennai    Overseas           151.0  1537.0
# 130          Nitish Rana     Kolkata      Indian            77.0  1820.0
# 131          Jason Holder    Lucknow    Overseas            26.0   189.0
#
#      Average  Strike_Rate  Wickets  Bowling_average  Economy  \
# 127    11.12       109.88    145.0            27.80     6.91
# 128    19.75       140.44     38.0            30.13     8.24
# 129    22.94       130.25    167.0            24.32     8.36
# 130    28.00       132.46      7.0            22.00     8.03
# 131    14.54       121.15     35.0            22.46     8.20
#
#      Bowling_Strike_Rate
# 127                24.12
# 128                21.95
# 129                17.44
# 130                16.43
# 131                16.43

# %%
#Cleaning the data by making the null or NAN values 0

Capped_Batters = Capped_Batters.fillna(0)
Capped_Bowlers = Capped_Bowlers.fillna(0)
Capped_Allrounders = Capped_Allrounders.fillna(0)
Capped_keepers = Capped_keepers.fillna(0)

# %%
#Checking null values in the data
print(Capped_Batters.isna().sum())
print(Capped_Bowlers.isna().sum())
print(Capped_Allrounders.isna().sum())
print(Capped_keepers.isna().sum())
# Out:
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
# Player Name            0
# Team                   0
# Nationality            0
# Matches_Played         0
# Runs                   0
# Average                0
# Strike_Rate            0
# Wickets                0
# Bowling_average        0
# Economy                0
# Bowling_Strike_Rate    0
# dtype: int64
# Player Name       0
# Team              0
# Nationality       0
# Matches_Played    0
# Runs              0
# Average           0
# Strike_Rate       0
# Catches           0
# Run_outs          0
# Stumps            0
# dtype: int64

# %% [markdown]
# ## Analysis

# %% [markdown]
# I will be performing an in-depth analysis of data pertaining to batters, bowlers, keepers, and all-rounders in order to identify the top players in each category. This analysis will involve evaluating various parameters to determine the most outstanding performers among batters, bowlers, keepers, and all-rounders.

# %%
#Analyzing the batters data

top_batters = Capped_Batters.loc[(Capped_Batters['Average'] >= 28.0) & (Capped_Batters['Matches_Played'] >= 80) & (Capped_Batters['Strike_Rate'] >= 125.00)]


#Sorting the data in descending order with respected to each parameter

top_batters_average = top_batters.sort_values('Average', ascending=False)
top_batters_strike_rate = top_batters.sort_values('Strike_Rate', ascending=False)
top_batters_runs = top_batters.sort_values('Runs', ascending=False)
top_batters_matches = top_batters.sort_values('Matches_Played', ascending=False)

# %%
top_batters_average
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 205     Rohit Sharma      Mumbai      Indian           213.0  5611.0    31.17
# 225  Suryakumar Yadav     Mumbai      Indian           115.0  2341.0    28.90
#
#      Strike_Rate
# 212       136.38
# 19        139.97
# 208       129.95
# 2         131.09
# 0         126.60
# 26        136.51
# 205       130.40
# 225       135.71

# %%
top_batters_strike_rate
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 225  Suryakumar Yadav     Mumbai      Indian           115.0  2341.0    28.90
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 205     Rohit Sharma      Mumbai      Indian           213.0  5611.0    31.17
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
#
#      Strike_Rate
# 19        139.97
# 26        136.51
# 212       136.38
# 225       135.71
# 2         131.09
# 205       130.40
# 208       129.95
# 0         126.60

# %%
top_batters_runs
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 205     Rohit Sharma      Mumbai      Indian           213.0  5611.0    31.17
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 225  Suryakumar Yadav     Mumbai      Indian           115.0  2341.0    28.90
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 208       129.95
# 0         126.60
# 205       130.40
# 19        139.97
# 212       136.38
# 2         131.09
# 225       135.71
# 26        136.51

# %%
top_batters_matches
# Out:
#           Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 205     Rohit Sharma      Mumbai      Indian           213.0  5611.0    31.17
# 208       Virat Kohli  Bangalore      Indian           207.0  6283.0    37.40
# 0      Shikhar Dhawan     Punjab      Indian           192.0  5783.0    34.63
# 19      David Warner       Delhi    Overseas           150.0  5449.0    41.60
# 225  Suryakumar Yadav     Mumbai      Indian           115.0  2341.0    28.90
# 2      Faf Du Plessis  Bangalore    Overseas           100.0  2935.0    34.94
# 212         KL Rahul     Lucknow      Indian            94.0  3273.0    47.43
# 26      David Miller     Gujarat    Overseas            89.0  1974.0    32.90
#
#      Strike_Rate
# 205       130.40
# 208       129.95
# 0         126.60
# 19        139.97
# 225       135.71
# 2         131.09
# 212       136.38
# 26        136.51

# %%
# Creating a dictionary to store the batters and their cumulative scores
batters_scores = {}

# Iterating over the top_batters DataFrame and calculating cumulative scores
for index, batter in top_batters.iterrows():
    batter_id = batter['Player Name']
    cumulative_score = 0
    # Adding scores based on the rankings in each parameter DataFrame
    cumulative_score += top_batters_average.index.get_loc(index)
    cumulative_score += top_batters_strike_rate.index.get_loc(index)
    cumulative_score += top_batters_runs.index.get_loc(index)
    cumulative_score += top_batters_matches.index.get_loc(index)
    batters_scores[batter_id] = cumulative_score

# Sorting the batters based on cumulative scores in ascending order
sorted_batters = sorted(batters_scores, key=batters_scores.get)

# Extracting the top 4 batters
top_4_batters = sorted_batters[:4]
print(top_4_batters)
# Out:
# ['David Warner ', 'Virat Kohli', 'KL Rahul ', 'Rohit Sharma ']

# %%
#Analyzing the bowlers data

top_bowlers = Capped_Bowlers.loc[(Capped_Bowlers['Economy'] <= 8.0) & (Capped_Bowlers['Bowling_average'] <= 27.0) & (Capped_Bowlers['Wickets'] >= 50)]


#Sorting the data in descending order with respected to each parameter

top_bowlers_average = top_bowlers.sort_values('Bowling_average')
top_bowlers_strike_rate = top_bowlers.sort_values('Bowling_Strike_Rate')
top_bowlers_wickets = top_bowlers.sort_values('Wickets', ascending=False)
top_bowlers_economy = top_bowlers.sort_values('Economy')
top_bowlers_matches = top_bowlers.sort_values('Matches_Played', ascending=False)

# %%
top_bowlers_average
# Out:
#            Player Name       Team Nationality  Matches_Played  Wickets  \
# 50   Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215     Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 45   Bhuvneshwar Kumar  Hyderabad      Indian           132.0    142.0
# 68     Sandeep Sharma      Punjab      Indian            99.0    112.0
#
#      Bowling_average  Economy  Bowling_Strike_Rate
# 50             22.28     7.59                17.61
# 215            23.05     7.42                18.63
# 45             25.27     7.30                20.77
# 68             25.44     7.78                19.62

# %%
top_bowlers_strike_rate
# Out:
#            Player Name       Team Nationality  Matches_Played  Wickets  \
# 50   Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215     Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 68     Sandeep Sharma      Punjab      Indian            99.0    112.0
# 45   Bhuvneshwar Kumar  Hyderabad      Indian           132.0    142.0
#
#      Bowling_average  Economy  Bowling_Strike_Rate
# 50             22.28     7.59                17.61
# 215            23.05     7.42                18.63
# 68             25.44     7.78                19.62
# 45             25.27     7.30                20.77

# %%
top_bowlers_wickets
# Out:
#            Player Name       Team Nationality  Matches_Played  Wickets  \
# 45   Bhuvneshwar Kumar  Hyderabad      Indian           132.0    142.0
# 50   Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215     Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 68     Sandeep Sharma      Punjab      Indian            99.0    112.0
#
#      Bowling_average  Economy  Bowling_Strike_Rate
# 45             25.27     7.30                20.77
# 50             22.28     7.59                17.61
# 215            23.05     7.42                18.63
# 68             25.44     7.78                19.62

# %%
top_bowlers_economy
# Out:
#            Player Name       Team Nationality  Matches_Played  Wickets  \
# 45   Bhuvneshwar Kumar  Hyderabad      Indian           132.0    142.0
# 215     Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 50   Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 68     Sandeep Sharma      Punjab      Indian            99.0    112.0
#
#      Bowling_average  Economy  Bowling_Strike_Rate
# 45             25.27     7.30                20.77
# 215            23.05     7.42                18.63
# 50             22.28     7.59                17.61
# 68             25.44     7.78                19.62

# %%
top_bowlers_matches
# Out:
#            Player Name       Team Nationality  Matches_Played  Wickets  \
# 45   Bhuvneshwar Kumar  Hyderabad      Indian           132.0    142.0
# 50   Yuzvendra Chahal   Rajasthan      Indian           114.0    139.0
# 215     Jasprit Bumrah     Mumbai      Indian           106.0    130.0
# 68     Sandeep Sharma      Punjab      Indian            99.0    112.0
#
#      Bowling_average  Economy  Bowling_Strike_Rate
# 45             25.27     7.30                20.77
# 50             22.28     7.59                17.61
# 215            23.05     7.42                18.63
# 68             25.44     7.78                19.62

# %%
# Creating a dictionary to store the bowlers and their cumulative scores
bowlers_scores = {}

# Iterating over the top_bowlers DataFrame and calculating cumulative scores
for index, bowler in top_bowlers.iterrows():
    bowler_id = bowler['Player Name']
    cumulative_score = 0
    # Adding scores based on the rankings in each parameter DataFrame
    cumulative_score += top_bowlers_average.index.get_loc(index)
    cumulative_score += top_bowlers_strike_rate.index.get_loc(index)
    cumulative_score += top_bowlers_wickets.index.get_loc(index)
    cumulative_score += top_bowlers_economy.index.get_loc(index)
    cumulative_score += top_bowlers_matches.index.get_loc(index)
    bowlers_scores[bowler_id] = cumulative_score

# Sorting the bowlers based on cumulative scores in descending order
sorted_bowlers = sorted(bowlers_scores, key=bowlers_scores.get)

# Extracting the top 3 bowlers
top_3_bowlers = sorted_bowlers[:3]
print(top_3_bowlers)
# Out:
# ['Yuzvendra Chahal ', 'Bhuvneshwar Kumar', 'Jasprit Bumrah']

# %%
#Analyzing the All-rounders data

top_allrounders = Capped_Allrounders.loc[(Capped_Allrounders['Matches_Played'] >= 50.0) & (Capped_Allrounders['Strike_Rate'] >= 130.0) &(Capped_Allrounders['Wickets'] >= 50)]


#Sorting the data in descending order with respected to each parameter

top_allrounders_bowling_average = top_allrounders.sort_values('Bowling_average')
top_allrounders_strike_rate = top_allrounders.sort_values('Bowling_Strike_Rate')
top_allrounders_wickets = top_allrounders.sort_values('Wickets', ascending=False)
top_allrounders_economy = top_allrounders.sort_values('Economy')
top_allrounders_matches = top_allrounders.sort_values('Matches_Played', ascending=False)
top_allrounders_average = top_allrounders.sort_values('Average', ascending=False)
top_allrounders_strike_rate = top_allrounders.sort_values('Strike_Rate', ascending=False)
top_allrounders_runs = top_allrounders.sort_values('Runs', ascending=False)

# %%
top_allrounders_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0   29.980
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0   29.310
# 129    Dwayne Bravo     Chennai    Overseas           151.0  1537.0   22.940
# 136    Krunal Pandya    Lucknow      Indian            84.0  1143.0   22.410
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0   15.640
# 132    Harshal Patel  Bangalore      Indian            63.0   187.0   11.000
# 221      Rashid Khan    Gujarat    Overseas            76.0   222.0    9.255
#
#      Strike_Rate  Wickets  Bowling_average  Economy  Bowling_Strike_Rate
# 233       149.77     65.0            31.62     8.78                21.60
# 204       178.57     72.0            26.40     9.05                17.51
# 129       130.25    167.0            24.32     8.36                17.44
# ...

# %%
top_allrounders_bowling_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 221      Rashid Khan    Gujarat    Overseas            76.0   222.0    9.255
# 132    Harshal Patel  Bangalore      Indian            63.0   187.0   11.000
# 129    Dwayne Bravo     Chennai    Overseas           151.0  1537.0   22.940
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0   15.640
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0   29.310
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0   29.980
# 136    Krunal Pandya    Lucknow      Indian            84.0  1143.0   22.410
#
#      Strike_Rate  Wickets  Bowling_average  Economy  Bowling_Strike_Rate
# 221       137.04     93.0            20.56     6.33                19.48
# 132       134.53     78.0            23.18     8.58                16.21
# 129       130.25    167.0            24.32     8.36                17.44
# ...

# %%
top_allrounders_wickets
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 129    Dwayne Bravo     Chennai    Overseas           151.0  1537.0   22.940
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0   15.640
# 221      Rashid Khan    Gujarat    Overseas            76.0   222.0    9.255
# 132    Harshal Patel  Bangalore      Indian            63.0   187.0   11.000
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0   29.310
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0   29.980
# 136    Krunal Pandya    Lucknow      Indian            84.0  1143.0   22.410
#
#      Strike_Rate  Wickets  Bowling_average  Economy  Bowling_Strike_Rate
# 129       130.25    167.0            24.32     8.36                17.44
# 232       161.69    143.0            24.53     6.74                21.83
# 221       137.04     93.0            20.56     6.33                19.48
# ...

# %%
top_allrounders_economy
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 221      Rashid Khan    Gujarat    Overseas            76.0   222.0    9.255
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0   15.640
# 136    Krunal Pandya    Lucknow      Indian            84.0  1143.0   22.410
# 129    Dwayne Bravo     Chennai    Overseas           151.0  1537.0   22.940
# 132    Harshal Patel  Bangalore      Indian            63.0   187.0   11.000
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0   29.980
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0   29.310
#
#      Strike_Rate  Wickets  Bowling_average  Economy  Bowling_Strike_Rate
# 221       137.04     93.0            20.56     6.33                19.48
# 232       161.69    143.0            24.53     6.74                21.83
# 136       138.55     51.0            34.76     7.37                28.31
# ...

# %%
top_allrounders_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0   29.980
# 129    Dwayne Bravo     Chennai    Overseas           151.0  1537.0   22.940
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0   15.640
# 136    Krunal Pandya    Lucknow      Indian            84.0  1143.0   22.410
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0   29.310
# 221      Rashid Khan    Gujarat    Overseas            76.0   222.0    9.255
# 132    Harshal Patel  Bangalore      Indian            63.0   187.0   11.000
#
#      Strike_Rate  Wickets  Bowling_average  Economy  Bowling_Strike_Rate
# 233       149.77     65.0            31.62     8.78                21.60
# 129       130.25    167.0            24.32     8.36                17.44
# 232       161.69    143.0            24.53     6.74                21.83
# ...

# %%
top_allrounders_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0   29.980
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0   29.310
# 129    Dwayne Bravo     Chennai    Overseas           151.0  1537.0   22.940
# 136    Krunal Pandya    Lucknow      Indian            84.0  1143.0   22.410
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0   15.640
# 132    Harshal Patel  Bangalore      Indian            63.0   187.0   11.000
# 221      Rashid Khan    Gujarat    Overseas            76.0   222.0    9.255
#
#      Strike_Rate  Wickets  Bowling_average  Economy  Bowling_Strike_Rate
# 233       149.77     65.0            31.62     8.78                21.60
# 204       178.57     72.0            26.40     9.05                17.51
# 129       130.25    167.0            24.32     8.36                17.44
# ...

# %%
top_allrounders_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0   29.310
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0   15.640
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0   29.980
# 136    Krunal Pandya    Lucknow      Indian            84.0  1143.0   22.410
# 221      Rashid Khan    Gujarat    Overseas            76.0   222.0    9.255
# 132    Harshal Patel  Bangalore      Indian            63.0   187.0   11.000
# 129    Dwayne Bravo     Chennai    Overseas           151.0  1537.0   22.940
#
#      Strike_Rate  Wickets  Bowling_average  Economy  Bowling_Strike_Rate
# 204       178.57     72.0            26.40     9.05                17.51
# 232       161.69    143.0            24.53     6.74                21.83
# 233       149.77     65.0            31.62     8.78                21.60
# ...

# %%
top_allrounders_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 233  Kieron Pollard      Mumbai    Overseas           178.0  3268.0   29.980
# 204    Andre Russell    Kolkata    Overseas            84.0  1700.0   29.310
# 129    Dwayne Bravo     Chennai    Overseas           151.0  1537.0   22.940
# 136    Krunal Pandya    Lucknow      Indian            84.0  1143.0   22.410
# 232    Sunil Narine     Kolkata    Overseas           134.0   954.0   15.640
# 221      Rashid Khan    Gujarat    Overseas            76.0   222.0    9.255
# 132    Harshal Patel  Bangalore      Indian            63.0   187.0   11.000
#
#      Strike_Rate  Wickets  Bowling_average  Economy  Bowling_Strike_Rate
# 233       149.77     65.0            31.62     8.78                21.60
# 204       178.57     72.0            26.40     9.05                17.51
# 129       130.25    167.0            24.32     8.36                17.44
# ...

# %%
# Creating a dictionary to store the all-rounders and their cumulative scores
allrounders_scores = {}

# Iterating over the top_allrounders DataFrame and calculating cumulative scores
for index, allrounder in top_allrounders.iterrows():
    allrounder_id = allrounder['Player Name']
    cumulative_score = 0
    # Adding scores based on the rankings in each parameter DataFrame
    cumulative_score += top_allrounders_bowling_average.index.get_loc(index)
    cumulative_score += top_allrounders_strike_rate.index.get_loc(index)
    cumulative_score += top_allrounders_wickets.index.get_loc(index)
    cumulative_score += top_allrounders_economy.index.get_loc(index)
    cumulative_score += top_allrounders_matches.index.get_loc(index)
    cumulative_score += top_allrounders_average.index.get_loc(index)
    cumulative_score += top_allrounders_strike_rate.index.get_loc(index)
    cumulative_score += top_allrounders_runs.index.get_loc(index)
    allrounders_scores[allrounder_id] = cumulative_score

# Sorting the all-rounders based on cumulative scores in ascending order
sorted_allrounders = sorted(allrounders_scores, key=allrounders_scores.get)

# Extracting the top 3 all-rounders
top_3_allrounders = sorted_allrounders[:3]
print(top_3_allrounders)
# Out:
# ['Sunil Narine ', 'Kieron Pollard ', 'Andre Russell']

# %%
#Analyzing the keepers data

top_keeper = Capped_keepers.loc[(Capped_keepers['Average'] >= 25.0) & (Capped_keepers['Matches_Played']>= 70) & (Capped_keepers['Strike_Rate'] >= 127.0)]


#Sorting the data in descending order with respected to each parameter

top_keeper_average = top_keeper.sort_values('Average', ascending=False)
top_keeper_strike_rate = top_keeper.sort_values('Strike_Rate', ascending=False)
top_keeper_runs = top_keeper.sort_values('Runs', ascending=False)
top_keeper_matches = top_keeper.sort_values('Matches_Played', ascending=False)
top_keeper_catches = top_keeper.sort_values('Catches', ascending=False)
top_keeper_runouts = top_keeper.sort_values('Run_outs', ascending=False)
top_keeper_stumps = top_keeper.sort_values('Stumps', ascending=False)

# %%
top_keeper_average
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 206       147.46     56.0       5.0    14.0
# 105       130.90     53.0       0.0    14.0
# 106       127.50     58.0      12.0     2.0
# 209       134.21     59.0       8.0    10.0
# 109       129.70    123.0      14.0    32.0

# %%
top_keeper_strike_rate
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 206       147.46     56.0       5.0    14.0
# 213       135.80    126.0      21.0    39.0
# 209       134.21     59.0       8.0    10.0
# 105       130.90     53.0       0.0    14.0
# 109       129.70    123.0      14.0    32.0
# 106       127.50     58.0      12.0     2.0

# %%
top_keeper_runs
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 109       129.70    123.0      14.0    32.0
# 106       127.50     58.0      12.0     2.0
# 209       134.21     59.0       8.0    10.0
# 206       147.46     56.0       5.0    14.0
# 105       130.90     53.0       0.0    14.0

# %%
top_keeper_matches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 109       129.70    123.0      14.0    32.0
# 106       127.50     58.0      12.0     2.0
# 209       134.21     59.0       8.0    10.0
# 206       147.46     56.0       5.0    14.0
# 105       130.90     53.0       0.0    14.0

# %%
top_keeper_catches
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 109       129.70    123.0      14.0    32.0
# 209       134.21     59.0       8.0    10.0
# 106       127.50     58.0      12.0     2.0
# 206       147.46     56.0       5.0    14.0
# 105       130.90     53.0       0.0    14.0

# %%
top_keeper_runouts
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 109       129.70    123.0      14.0    32.0
# 106       127.50     58.0      12.0     2.0
# 209       134.21     59.0       8.0    10.0
# 206       147.46     56.0       5.0    14.0
# 105       130.90     53.0       0.0    14.0

# %%
top_keeper_stumps
# Out:
#          Player Name       Team Nationality  Matches_Played    Runs  Average  \
# 213         MS Dhoni    Chennai      Indian           220.0  4746.0    39.50
# 109   Dinesh Karthik  Bangalore      Indian           213.0  4046.0    25.80
# 105  Quinton De Kock    Lucknow    Overseas            77.0  2256.0    31.30
# 206    Rishabh Pant       Delhi      Indian            84.0  2498.0    35.18
# 209     Sanju Samson  Rajasthan      Indian           121.0  3068.0    29.22
# 106    Ambati Rayudu    Chennai      Indian           175.0  3916.0    29.40
#
#      Strike_Rate  Catches  Run_outs  Stumps
# 213       135.80    126.0      21.0    39.0
# 109       129.70    123.0      14.0    32.0
# 105       130.90     53.0       0.0    14.0
# 206       147.46     56.0       5.0    14.0
# 209       134.21     59.0       8.0    10.0
# 106       127.50     58.0      12.0     2.0

# %%
# Creating a dictionary to store the keepers and their cumulative scores
keepers_scores = {}

# Iterating over the top_keeper DataFrame and calculating cumulative scores
for index, keeper in top_keeper.iterrows():
    keeper_id = keeper['Player Name']
    cumulative_score = 0
    # Adding scores based on the rankings in each parameter DataFrame
    cumulative_score += top_keeper_average.index.get_loc(index)
    cumulative_score += top_keeper_strike_rate.index.get_loc(index)
    cumulative_score += top_keeper_runs.index.get_loc(index)
    cumulative_score += top_keeper_matches.index.get_loc(index)
    cumulative_score += top_keeper_catches.index.get_loc(index)
    cumulative_score += top_keeper_runouts.index.get_loc(index)
    cumulative_score += top_keeper_stumps.index.get_loc(index)
    keepers_scores[keeper_id] = cumulative_score

# Sorting the keepers based on cumulative scores in ascending order
sorted_keepers = sorted(keepers_scores, key=keepers_scores.get)

# Extracting the top 1 keepers
top_1_keepers = sorted_keepers[:1]
print(top_1_keepers)
# Out:
# ['MS Dhoni']

# %% [markdown]
# ## Visulization for enhanced analysis

# %% [markdown]
# I am creating visualizations based on the analysis mentioned earlier. These visualizations aim to present the findings in a user-friendly manner, making it easier for non-technical stakeholders to comprehend the information. By using clear and concise visuals, I hope to assist them in making informed decisions.

# %%
#visulization for batters data
#plot shows each of the top batters strike rate.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Strike_Rate', data=top_batters, order=top_batters.sort_values('Strike_Rate')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
#visulization for batters data
#plot shows each of the top batters run.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Runs', data=top_batters, order=top_batters.sort_values('Runs')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Runs'>

# %%
#visulization for batters data
#plot shows each of the top batters average.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Average', data=top_batters, order=top_batters.sort_values('Average')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
#visulization for batters data
#plot shows each of the top batters matches played.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Matches_Played', data=top_batters, order=top_batters.sort_values('Matches_Played')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
#visulization for bowlers data
#plot shows each of the top bowlers bowling average.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Bowling_average', data=top_bowlers, order=top_bowlers.sort_values('Bowling_average', ascending=False)['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Bowling_average'>

# %%
#visulization for bowlers data
#plot shows each of the top bowlers economy.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Economy', data=top_bowlers, order=top_bowlers.sort_values('Economy', ascending=False)['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Economy'>

# %%
#visulization for bowlers data
#plot shows each of the top bowlers wicket.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Wickets', data=top_bowlers, order=top_bowlers.sort_values('Wickets')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Wickets'>

# %%
#visulization for bowlers data
#plot shows each of the top bowlers Matches Played.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Matches_Played', data=top_bowlers, order=top_bowlers.sort_values('Matches_Played')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
#visulization for allrounders data
#plot shows each of the top allrounders wickets.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Wickets', data=top_allrounders, order=top_allrounders.sort_values('Wickets')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Wickets'>

# %%
#visulization for allrounders data
#plot shows each of the top allrounders average.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Average', data=top_allrounders, order=top_allrounders.sort_values('Average')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
#visulization for allrounders data
#plot shows each of the top allrounders strike rate.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Strike_Rate', data=top_allrounders,  order=top_allrounders.sort_values('Strike_Rate')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
#visulization for allrounders data
#plot shows each of the top allrounders Matches Played.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Matches_Played', data=top_allrounders,  order=top_allrounders.sort_values('Matches_Played')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %%
#visulization for keeper data
#plot shows each of the top keeper average.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Average', data=top_keeper, order=top_keeper.sort_values('Average')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Average'>

# %%
#visulization for keeper data
#plot shows each of the top keeper Strike_rate.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Strike_Rate', data=top_keeper, order=top_keeper.sort_values('Strike_Rate')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Strike_Rate'>

# %%
#visulization for keeper data
#plot shows each of the top keeper catches.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Catches', data=top_keeper, order=top_keeper.sort_values('Catches')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Catches'>

# %%
#visulization for keeper data
#plot shows each of the top keeper stumps.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Stumps', data=top_keeper, order=top_keeper.sort_values('Stumps')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Stumps'>

# %%
#visulization for keeper data
#plot shows each of the top keeper Matches Played.
plt.figure(figsize=(20,10))
sns.barplot(x='Player Name', y='Matches_Played', data=top_keeper, order=top_keeper.sort_values('Matches_Played')['Player Name'])
# Out:
# <AxesSubplot:xlabel='Player Name', ylabel='Matches_Played'>

# %% [markdown]
# ## Presenting All Time Best Playing 11 based on Above Analysis

# %%
# Create a DataFrame for each category with the selected players
batters_df = top_batters.loc[top_batters['Player Name'].isin(top_4_batters[:4])]
bowlers_df = top_bowlers.loc[top_bowlers['Player Name'].isin(top_3_bowlers[:3])]
allrounders_df = top_allrounders.loc[top_allrounders['Player Name'].isin(top_3_allrounders[:3])]
keepers_df = top_keeper.loc[top_keeper['Player Name'].isin(top_1_keepers[:1])]

# Print the selected batters
print("Selected Batters:")
print(batters_df.to_string(index=False))
print()

# Print the selected bowlers
print("Selected Bowlers:")
print(bowlers_df.to_string(index=False))
print()

# Print the selected all-rounders
print("Selected All-Rounders:")
print(allrounders_df.to_string(index=False))
print()

# Print the selected keepers
print("Selected Keepers:")
print(keepers_df.to_string(index=False))
# Out:
# Selected Batters:
#   Player Name      Team Nationality  Matches_Played   Runs  Average  Strike_Rate
# David Warner      Delhi    Overseas           150.0 5449.0    41.60       139.97
# Rohit Sharma     Mumbai      Indian           213.0 5611.0    31.17       130.40
#   Virat Kohli Bangalore      Indian           207.0 6283.0    37.40       129.95
#     KL Rahul    Lucknow      Indian            94.0 3273.0    47.43       136.38
#
# Selected Bowlers:
#       Player Name      Team Nationality  Matches_Played  Wickets  Bowling_average  Economy  Bowling_Strike_Rate
# Bhuvneshwar Kumar Hyderabad      Indian           132.0    142.0            25.27     7.30                20.77
# Yuzvendra Chahal  Rajasthan      Indian           114.0    139.0            22.28     7.59                17.61
#    Jasprit Bumrah    Mumbai      Indian           106.0    130.0            23.05     7.42                18.63
#
# Selected All-Rounders:
# ...

# %%
# Concatenate the selected players' names into a single list
selected_players = list(batters_df['Player Name']) + list(keepers_df['Player Name']) + list(allrounders_df['Player Name']) + list(bowlers_df['Player Name'])

# Print the selected players' names
print("All Time Best Playing 11:-")
for player_name in selected_players:
    print(player_name)
# Out:
# All Time Best Playing 11:-
# David Warner
# Rohit Sharma
# Virat Kohli
# KL Rahul
# MS Dhoni
# Andre Russell
# Sunil Narine
# Kieron Pollard
# Bhuvneshwar Kumar
# Yuzvendra Chahal
# Jasprit Bumrah

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In conclusion, this project aims to identify the all-time best playing 11 for an IPL team based on players' performance in the Indian Premier League. By analyzing extensive data from past IPL seasons and considering various parameters, such as batting averages, strike rates, bowling averages, economy rates, wicketkeeping performances, and all-round contributions, the project will determine the best players for each category. The resulting all-time best playing 11 will provide valuable insights into the most successful and impactful players in the history of the IPL.
#
# Through the use of visualizations and presenting the findings in a concise and understandable manner, this project not only facilitates decision-making for stakeholders but also makes the information accessible to individuals without a technical background. The identified team composition, consisting of four batters, three all-rounders, one keeper, and three bowlers, takes into account the ratio of players from successful teams in recent events.
#
# The all-time best playing 11 serves as a valuable resource for fans, team management, and cricket enthusiasts, providing a comprehensive understanding of the players who have made the greatest contributions to the IPL. Whether for strategic purposes or for appreciating the achievements of these players, this project's findings will contribute to a deeper appreciation and knowledge of the league's history.
